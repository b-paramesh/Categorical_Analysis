# %% [markdown]
# <a href="https://colab.research.google.com/github/AnveshAnnepaga/AI_DS/blob/main/categorical_vs_numerical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
df = sns.load_dataset("taxis")

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1     0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2     2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4     1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...    ...    ...     ...          ...                    ...
# 6428  1.06    0.0   6.36   green  credit card      East Harlem North
# 6429  0.00    0.0  58.80   green  credit card                Jamaica
# 6430  0.00    0.0  17.30   green         cash    Crown Heights North
# 6431  0.00    0.0   6.80   green  credit card          East New York
# 6432  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6428              Central Harlem North      Manhattan       Manhattan
# 6429  East Concourse/Concourse Village         Queens           Bronx
# 6430                    Bushwick North       Brooklyn        Brooklyn
# 6431      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6432                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6433 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# 50%       1.000000     1.640000     9.500000     1.70000     0.000000
# 75%       2.000000     3.210000    15.000000     2.80000     0.000000
# max       6.000000    36.700000   150.000000    33.20000    24.020000
# std       1.203768     3.827867    11.551804     2.44856     1.415267
#
#              total
# count  6433.000000
# mean     18.517794
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000
# std      13.815570

# %%
df.describe(include="object")
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6433         6389            6407                   6388
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5451         4577             230                    245
#
#        pickup_borough dropoff_borough
# count            6407            6388
# unique              4               5
# top         Manhattan       Manhattan
# freq             5268            5206

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan
# 3         Yorkville West      Manhattan       Manhattan
# 4         Yorkville West      Manhattan       Manhattan

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
df.shape[0] - df.dropna().shape[0]
# Out:
# 92

# %%
((df.shape[0] - df.dropna().shape[0])/df.shape[0])*100 #percentage of the deleting records
# Out:
# 1.4301259132597544

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (6341, 14)

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6341                           6341
# mean   2019-03-16 08:30:26.574830080  2019-03-16 08:44:47.525784832
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:28:20            2019-03-08 15:54:00
# 50%              2019-03-15 21:57:47            2019-03-15 22:07:48
# 75%              2019-03-23 17:45:29            2019-03-23 17:57:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare          tip        tolls  \
# count  6341.000000  6341.000000  6341.000000  6341.000000  6341.000000
# mean      1.544078     2.997707    12.887931     1.972703     0.314793
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# 25%       1.000000     0.990000     6.500000     0.000000     0.000000
# 50%       1.000000     1.650000     9.500000     1.750000     0.000000
# 75%       2.000000     3.200000    15.000000     2.820000     0.000000
# max       6.000000    36.700000   150.000000    23.190000    24.020000
# std       1.207948     3.719775    10.722249     2.361897     1.369174
#
#              total
# count  6341.000000
# mean     18.310263
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000
# std      12.950365

# %%
df.describe(include="object")
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6341         6341            6341                   6341
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5373         4546             227                    244
#
#        pickup_borough dropoff_borough
# count            6341            6341
# unique              4               5
# top         Manhattan       Manhattan
# freq             5226            5172

# %%
df.reset_index(drop=True)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6336 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6337 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6338 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6339 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6340 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1     0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2     2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4     1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...    ...    ...     ...          ...                    ...
# 6336  1.06    0.0   6.36   green  credit card      East Harlem North
# 6337  0.00    0.0  58.80   green  credit card                Jamaica
# 6338  0.00    0.0  17.30   green         cash    Crown Heights North
# 6339  0.00    0.0   6.80   green  credit card          East New York
# 6340  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6336              Central Harlem North      Manhattan       Manhattan
# 6337  East Concourse/Concourse Village         Queens           Bronx
# 6338                    Bushwick North       Brooklyn        Brooklyn
# 6339      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6340                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6341 rows x 14 columns]

# %% [markdown]
# ***********EDA******

# %% [markdown]
# tip is the target column

# %% [markdown]
# tip is the numerical feature , analyze with color feature which is categorical

# %%
df.color.value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %% [markdown]
# graphical analysis of categorical data

# %%
sns.barplot(x=df.color,y=df.tip,estimator = 'std')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %% [markdown]
# Yellow color has more values than the green color , these color column has

# %%
sns.barplot(x=df.color,y=df.tip,estimator = 'mean')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
import matplotlib.pyplot as plt
sns.histplot(x=df.tip,hue=df.color,kde=True,color=['green','yellow'])
plt.show()

# %% [markdown]
# Color has a strong influence on tip behavior
#
# Yellow is associated with:
# * More frequent tipping
# * Higher tip amounts
#
# Green is associated with:
#
#   * Smaller, more conservative tips
#
# color is the meaningful feature to predict tip

# %% [markdown]
# Hypothesis:
#
# * H0 : distribution of yellow tip == green tip
# * H1 : distributioin of yellow tip != green tip

# %%
yellow_tip = df['tip'][df.color=='yellow']
green_tip = df['tip'][df.color=='green']

# %%
yellow_tip.shape
# Out:
# (5373,)

# %%
green_tip.shape
# Out:
# (968,)

# %%
from scipy import stats
t_stat, p_val = stats.ttest_ind(yellow_tip,green_tip)

print("T-statistic:", t_stat)
print("P-value:", p_val)


if p_val < 0.05: # 0.05 is the signicance level(alpha)
  print("Reject the null hypothesis")
else:
  print("Fail to reject the null hypothesis")
# Out:
# T-statistic: 17.05932566128597
# P-value: 7.791088119489451e-64
# Reject the null hypothesis

# %% [markdown]
# There is effect of color on tip column  ( we can confirm this by looking at p_value which is 0.000000000000000000079 outoff 1% probability)

# %% [markdown]
# payment columns with respect to tip

# %%
df.payment.value_counts()
# Out:
# payment
# credit card    4546
# cash           1795
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Mean tip by payment
sns.barplot(x=df.payment,y=df.tip,estimator='mean',ax=axes[0])
axes[0].set_title('Mean Tip by Payment')

# Std deviation of tip by payment
sns.barplot(x=df.paymenty=df.tip,estimator='std,ax=axes[1]')
axes[1].set_title('Tip Std Dev by Payment')

# Tip distribution by payment
sns.histplot(x=df.tip,hue=df.payment,kde=True,ax=axes[2])
axes[2].set_title('Tip Distribution by Payment')

plt.show()

# %% [markdown]
# Hypothesis:
#
# H0: mean type is differ of cash == credit card
#
# H1: mean type is differ of cash != credit card

# %%
creditcard_tip = df['tip'][df.payment=='credit card']
cash_tip = df['tip'][df.payment=='cash']

# %%
creditcard_tip.shape
# Out:
# (4546,)

# %%
cash_tip.shape
# Out:
# (1795,)

# %%
from scipy import stats
t_stat,p_value = stats.ttest_ind(creditcard_tip,cash_tip)

print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: 49.09538452722153
# P-value: 0.0

# %%
if(p_value < 0.05):
  print("Reject the null hypothesis")
else:
  print("Fail to reject the null hypothesis")
# Out:
# Reject the null hypothesis

# %%
df['pickup_borough'].unique()
# Out:
# array(['Manhattan', 'Queens', 'Bronx', 'Brooklyn'], dtype=object)

# %%
df['pickup_borough'].value_counts()
# Out:
# pickup_borough
# Manhattan    5226
# Queens        638
# Brooklyn      378
# Bronx          99
# Name: count, dtype: int64

# %%
sns.countplot(x=df['pickup_borough'], palette='Set2') #univariant
# Out:
# /tmp/ipython-input-4178985149.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['pickup_borough'], palette='Set2') #univariant
# <Axes: xlabel='pickup_borough', ylabel='count'>

# %%
sns.barplot(x=df['pickup_borough'], y=df['tip'], palette='Set2')
# Out:
# /tmp/ipython-input-1162269297.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'], y=df['tip'], palette='Set2')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
sns.barplot(x=df['pickup_borough'], y=df['tip'], palette='Set2',estimator='mean')
# Out:
# /tmp/ipython-input-2569034154.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'], y=df['tip'], palette='Set2',estimator='mean')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
sns.barplot(x=df['pickup_borough'], y=df['tip'], palette='Set2',estimator='std')
# Out:
# /tmp/ipython-input-1163063915.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'], y=df['tip'], palette='Set2',estimator='std')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['pickup_borough']).mean()
# Out:
# pickup_borough
# Bronx        0.148586
# Brooklyn     0.979127
# Manhattan    1.945597
# Queens       3.066458
# Name: tip, dtype: float64

# %%
df['tip'].groupby(df['pickup_borough']).std()
# Out:
# pickup_borough
# Bronx        0.897261
# Brooklyn     1.674487
# Manhattan    1.997736
# Queens       4.323951
# Name: tip, dtype: float64

# %%
sns.histplot  (x=df['tip'], hue=df['pickup_borough'], kde=True,bins=30)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# Hypothesis:
#
# H0 : distributoin of tip is the same across all pickup_borough categories
#
# H1 : At least one category has a different distribution of tip

# %%
manhattan_tip = df['tip'][df.pickup_borough=='Manhattan']
queens_tip = df['tip'][df.pickup_borough=='Queens']
bronx_tip = df['tip'][df.pickup_borough=='Bronx']
brooklyn_tip = df['tip'][df.pickup_borough=='Brooklyn']

# %%
manhattan_tip.shape
# Out:
# (5226,)

# %%
queens_tip.shape
# Out:
# (638,)

# %%
bronx_tip.shape
# Out:
# (99,)

# %%
brooklyn_tip.shape
# Out:
# (378,)

# %%
##ANOVA Test

f_stat,p_val = stats.f_oneway(manhattan_tip,queens_tip,bronx_tip,brooklyn_tip)

print("F-statistic:", f_stat)
print("P-value:", p_val)
# Out:
# F-statistic: 91.5793383185057
# P-value: 5.155109332422435e-58

# %%
alpha = 0.05
if p_val < alpha:
  print("reject null hypothesis")
else:
  print("fail to reject null hypothes")
# Out:
# reject null hypothesis

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
tukey_results = pairwise_tukeyhsd(df['tip'], df['pickup_borough'])
print(tukey_results)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#   group1    group2  meandiff p-adj lower  upper  reject
# -------------------------------------------------------
#     Bronx  Brooklyn   0.8305 0.008 0.1595 1.5015   True
#     Bronx Manhattan    1.797   0.0  1.194    2.4   True
#     Bronx    Queens   2.9179   0.0 2.2759 3.5599   True
#  Brooklyn Manhattan   0.9665   0.0 0.6499  1.283   True
#  Brooklyn    Queens   2.0873   0.0 1.7016 2.4731   True
# Manhattan    Queens   1.1209   0.0 0.8716 1.3701   True
# -------------------------------------------------------

# %%
sns.countplot(x=df['dropoff_borough'], palette='Set2') #univariant
# Out:
# /tmp/ipython-input-1207355554.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['dropoff_borough'], palette='Set2') #univariant
# <Axes: xlabel='dropoff_borough', ylabel='count'>

# %%
sns.barplot(x=df['dropoff_borough'], y=df['tip'], palette='Set2')
# Out:
# /tmp/ipython-input-2598855201.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['dropoff_borough'], y=df['tip'], palette='Set2')
# <Axes: xlabel='dropoff_borough', ylabel='tip'>

# %%
sns.barplot(x=df['dropoff_borough'], y=df['tip'], palette='Set2',estimator='mean')
# Out:
# /tmp/ipython-input-3144836048.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['dropoff_borough'], y=df['tip'], palette='Set2',estimator='mean')
# <Axes: xlabel='dropoff_borough', ylabel='tip'>

# %%
sns.barplot(x=df['dropoff_borough'], y=df['tip'], palette='Set2',estimator='std')
# Out:
# /tmp/ipython-input-2149091415.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['dropoff_borough'], y=df['tip'], palette='Set2',estimator='std')
# <Axes: xlabel='dropoff_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['dropoff_borough']).mean()
# Out:
# dropoff_borough
# Bronx             0.534706
# Brooklyn          1.921590
# Manhattan         1.964321
# Queens            2.422022
# Staten Island    14.165000
# Name: tip, dtype: float64

# %%
df['tip'].groupby(df['dropoff_borough']).std()
# Out:
# dropoff_borough
# Bronx            1.788795
# Brooklyn         2.896229
# Manhattan        2.052074
# Queens           3.947016
# Staten Island    2.976920
# Name: tip, dtype: float64

# %%
sns.histplot  (x=df['tip'], hue=df['dropoff_borough'], kde=True,bins=30)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
df.dropoff_borough.value_counts()
# Out:
# dropoff_borough
# Manhattan        5172
# Queens            534
# Brooklyn          497
# Bronx             136
# Staten Island       2
# Name: count, dtype: int64

# %%
manhattan_tip = df['tip'][df.dropoff_borough=='Manhattan']
queens_tip = df['tip'][df.dropoff_borough=='Queens']
bronx_tip = df['tip'][df.dropoff_borough=='Bronx']
brooklyn_tip = df['tip'][df.dropoff_borough=='Brooklyn']
staten_island_tip = df['tip'][df.dropoff_borough=='Staten Island']

# %%
manhattan_tip.shape
# Out:
# (5172,)

# %%
queens_tip.shape
# Out:
# (534,)

# %%
bronx_tip.shape
# Out:
# (136,)

# %%
brooklyn_tip.shape
# Out:
# (497,)

# %%
staten_island_tip.shape
# Out:
# (2,)

# %% [markdown]
# Hypothesis:
#
# H0 : distributoin of tip is the same across all dropoff_borough categories
#
# H1 : At least one category has a different distribution of tip

# %%
##ANOVA Test

f_stat,p_val = stats.f_oneway(manhattan_tip,queens_tip,bronx_tip,brooklyn_tip,staten_island_tip)

print("F-statistic:", f_stat)
print("P-value:", p_val)
# Out:
# F-statistic: 31.42417796696829
# P-value: 5.87859571331583e-26

# %%
alpha = 0.05
if p_val < alpha:
  print("reject null hypothesis")
else:
  print("fail to reject null hypothes")
# Out:
# reject null hypothesis

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
tukey_results = pairwise_tukeyhsd(df['tip'], df['dropoff_borough'])
print(tukey_results)
# Out:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#   group1      group2    meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#     Bronx      Brooklyn   1.3869    0.0  0.7691  2.0046   True
#     Bronx     Manhattan   1.4296    0.0  0.8751  1.9842   True
#     Bronx        Queens   1.8873    0.0  1.2742  2.5005   True
#     Bronx Staten Island  13.6303    0.0  9.0833 18.1773   True
#  Brooklyn     Manhattan   0.0427 0.9952 -0.2571  0.3425  False
#  Brooklyn        Queens   0.5004 0.0055  0.1026  0.8983   True
#  Brooklyn Staten Island  12.2434    0.0  7.7204 16.7664   True
# Manhattan        Queens   0.4577 0.0002  0.1675  0.7479   True
# Manhattan Staten Island  12.2007    0.0  7.6859 16.7154   True
#    Queens Staten Island   11.743    0.0  7.2206 16.2653   True
# --------------------------------------------------------------

# %%
df['dropoff_zone'].value_counts()
# Out:
# dropoff_zone
# Upper East Side North    245
# Murray Hill              220
# Midtown Center           215
# Upper East Side South    177
# Midtown East             176
#                         ...
# Queensboro Hill            1
# Homecrest                  1
# Madison                    1
# Morrisania/Melrose         1
# Brooklyn Navy Yard         1
# Name: count, Length: 203, dtype: int64

# %%
df['dropoff_zone'].unique()
# Out:
# array(['UN/Turtle Bay South', 'Upper West Side South', 'West Village',
#        'Yorkville West', 'Midtown East', 'Two Bridges/Seward Park',
#        'Flatiron', 'Midtown Center', 'Central Park', 'Astoria',
#        'Manhattan Valley', 'Times Sq/Theatre District', 'Clinton East',
#        'Meatpacking/West Village West', 'East Harlem South',
#        'East Chelsea', 'Kips Bay', 'Murray Hill',
#        'Sutton Place/Turtle Bay North', 'Midtown North', 'Gramercy',
#        'Midtown South', 'Seaport', 'Lenox Hill West', 'East Harlem North',
#        'Garment District', 'West Chelsea/Hudson Yards', 'Clinton West',
#        'Lenox Hill East', 'Carroll Gardens', nan,
#        'Washington Heights South', 'Battery Park City',
#        'Penn Station/Madison Sq West', 'Union Sq', 'Sunnyside',
#        'Lincoln Square West', 'Upper East Side North',
#        'Financial District North', 'Lower East Side', 'Yorkville East',
#        'Upper West Side North', 'Jackson Heights',
#        'Upper East Side South', 'Chinatown',
#        'Stuy Town/Peter Cooper Village', 'Morningside Heights',
#        'Lincoln Square East', 'Little Italy/NoLiTa',
#        'Downtown Brooklyn/MetroTech', 'DUMBO/Vinegar Hill',
#        'Greenwich Village South', 'LaGuardia Airport', 'East Village',
#        'JFK Airport', 'Marble Hill', 'Greenwich Village North',
#        'Williamsburg (North Side)', 'Brooklyn Heights',
#        'Riverdale/North Riverdale/Fieldston', 'Steinway',
#        'Sheepshead Bay', 'Crown Heights North', 'TriBeCa/Civic Center',
#        'Midwood', 'Alphabet City', 'Boerum Hill',
#        'Financial District South', 'Cypress Hills', 'Park Slope',
#        'Central Harlem', 'North Corona', 'Greenpoint',
#        'Long Island City/Hunters Point', 'Hillcrest/Pomonok',
#        'Bloomingdale', 'Baisley Park', 'Crown Heights South',
#        'Soundview/Castle Hill', 'World Trade Center', 'Randalls Island',
#        'Melrose South', 'Columbia Street', 'Williamsburg (South Side)',
#        'SoHo', 'Hudson Sq', 'Fort Greene', 'Cobble Hill', 'Clinton Hill',
#        'Central Harlem North', 'East Flushing', 'Old Astoria',
#        'Forest Hills', 'Briarwood/Jamaica Hills', 'East New York',
#        'Ridgewood', 'Elmhurst', 'East Williamsburg',
#        'Williamsbridge/Olinville', 'University Heights/Morris Heights',
#        'Bushwick South', 'Flushing Meadows-Corona Park',
#        'Long Island City/Queens Plaza', 'Manhattanville',
#        'Elmhurst/Maspeth', 'Inwood', 'Woodhaven', 'Hamilton Heights',
#        'Middle Village', 'Prospect Heights', 'Richmond Hill',
#        'Mount Hope', 'Bushwick North', 'Canarsie', 'Gowanus',
#        'Washington Heights North', 'Westchester Village/Unionport',
#        'Queens Village', 'Woodside', 'Bedford', 'Highbridge',
#        'Stuyvesant Heights', 'Queensbridge/Ravenswood',
#        'East Flatbush/Farragut', 'Mott Haven/Port Morris',
#        'Prospect-Lefferts Gardens', 'Sunset Park West', 'South Jamaica',
#        'Howard Beach', 'South Williamsburg', 'Woodlawn/Wakefield',
#        'Rego Park', 'West Concourse', 'Manhattan Beach', 'Battery Park',
#        'Bronxdale', 'West Brighton', 'Flatlands', 'Glendale',
#        'East Concourse/Concourse Village', 'Ozone Park',
#        'South Ozone Park', 'Norwood', 'Parkchester', 'East Tremont',
#        'Douglaston', 'Windsor Terrace', 'Bensonhurst West', 'Kew Gardens',
#        'Flatbush/Ditmas Park', 'Starrett City', 'Roosevelt Island',
#        'Bay Ridge', 'Saint Albans', 'Pelham Parkway', 'Prospect Park',
#        'Jamaica', 'Murray Hill-Queens', 'Stapleton', 'Maspeth',
#        'Dyker Heights', 'Allerton/Pelham Gardens', 'Co-Op City',
#        'Belmont', 'Bensonhurst East', 'Kew Gardens Hills',
#        'Crotona Park East', 'Van Cortlandt Village',
#        'Springfield Gardens South', 'Corona', 'Brownsville', 'Red Hook',
#        'Bayside', 'Van Nest/Morris Park', 'Gravesend', 'Oakland Gardens',
#        'Claremont/Bathgate', 'Ocean Hill', 'Brighton Beach',
#        'Spuyten Duyvil/Kingsbridge', 'Kingsbridge Heights',
#        'Soundview/Bruckner', 'Fresh Meadows', 'East Elmhurst',
#        'Hunts Point', 'Cambria Heights', 'Whitestone',
#        'East Flatbush/Remsen Village', 'Rosedale', 'Inwood Hill Park',
#        'Bedford Park', 'Jamaica Estates', 'Borough Park', 'Flushing',
#        'Auburndale', 'Bath Beach', 'Queensboro Hill',
#        'Morrisania/Melrose', 'Madison', 'Homecrest', 'Eastchester',
#        'College Point', 'Brooklyn Navy Yard', 'Marine Park/Mill Basin'],
#       dtype=object)

# %%
from scipy import stats
categories = [
    group['tip'].dropna().values
    for _, group in df.groupby('dropoff_zone')
]

# One-way ANOVA (use * to unpack)
f_stat, p_val = stats.f_oneway(*categories)

print("F-statistic:", f_stat)
print("p-value:", p_val)
alpha = 0.05
if p_val < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# F-statistic: 5.629811248150463
# p-value: 1.8902497843624454e-116
# Reject null hypothesis

# %%
import matplotlib.pyplot as plt
sns.histplot(df['tip'],kde=True)
plt.show()

# %%
sns.histplot(df['fare'],kde=True)
plt.show()

# %%
sns.histplot(df['passengers'],kde=True)
plt.show()

# %%
sns.histplot(df['tip'],kde=True)
plt.show()

# %%
r, p_val = stats.spearmanr(df['tip'], df['fare'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: there is no relationship.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.30804802505745693
# P-value: 1.8889690809484477e-141
# Reject null hypothesis: there is no relationship.

# %%
sns.histplot(df['total'],kde=True)
plt.show()

# %%
sns.histplot(df['tolls'],kde=True)
plt.show()

# %%
sns.scatterplot(x=df.tip,y=df.tolls)
plt.show()

# %%
sns.scatterplot(x=df.tip,y=df.tolls)
plt.show()

# %%
sns.scatterplot(x=df.tip,y=df.passengers)
plt.show()

# %%
# Compute Pearson correlation
r, p_val = stats.pearsonr(df['tip'], df['fare'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: Significant correlation exists.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.4886124004721835
# P-value: 0.0
# Reject null hypothesis: Significant correlation exists.

# %%
# Compute Pearson correlation
r, p_val = stats.pearsonr(df['tip'], df['passengers'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: Significant correlation exists.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.021099301529590466
# P-value: 0.09061742405588158
# Fail to reject null hypothesis: No significant correlation.

# %%
sns.scatterplot(x=df.tip,y=df.fare)
plt.show()

# %%
r, p_val = stats.spearmanr(df['tip'], df['tolls'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: there is no relationship.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.17397405748923409
# P-value: 6.843376762990616e-45
# Reject null hypothesis: there is no relationship.

# %%
# Compute Pearson correlation
r, p_val = stats.pearsonr(df['tip'], df['fare'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: Significant correlation exists.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.4886124004721835
# P-value: 0.0
# Reject null hypothesis: Significant correlation exists.

# %%
# Compute Pearson correlation
r, p_val = stats.pearsonr(df['tip'], df['distance'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: Significant correlation exists.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.4525886565083947
# P-value: 1.8e-322
# Reject null hypothesis: Significant correlation exists.

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1     0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2     2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4     1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...    ...    ...     ...          ...                    ...
# 6428  1.06    0.0   6.36   green  credit card      East Harlem North
# 6429  0.00    0.0  58.80   green  credit card                Jamaica
# 6430  0.00    0.0  17.30   green         cash    Crown Heights North
# 6431  0.00    0.0   6.80   green  credit card          East New York
# 6432  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6428              Central Harlem North      Manhattan       Manhattan
# 6429  East Concourse/Concourse Village         Queens           Bronx
# 6430                    Bushwick North       Brooklyn        Brooklyn
# 6431      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6432                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6433 rows x 14 columns]

# %%
df.passengers.skew()  ## range is from -0.5 to +0.5
# Out:
# np.float64(2.3591434589875453)

# %%
df.total.skew()  ## range is from -0.5 to +0.5
# Out:
# np.float64(3.0933326288688754)

# %%
df.fare.skew()  ## range is from -0.5 to +0.5
# Out:
# np.float64(3.217462794607763)

# %%
df.distance.skew()  ## range is from -0.5 to +0.5
# Out:
# np.float64(3.0082057890318215)

# %%
r, p_val = stats.spearmanr(df['tip'], df['passengers'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: there is no relationship.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.03138925905741925
# P-value: 0.011811129244345143
# Reject null hypothesis: there is no relationship.

# %%
r, p_val = stats.spearmanr(df['tip'], df['total'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: there is no relationship.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.4992895514701028
# P-value: 0.0
# Reject null hypothesis: there is no relationship.

# %%
r, p_val = stats.spearmanr(df['tip'], df['distance'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: there is no relationship.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.2873087960440919
# P-value: 1.690346022049497e-122
# Reject null hypothesis: there is no relationship.

# %%
df.passengers.skew()  ## range is from -0.5 to +0.5
# Out:
# np.float64(2.3591434589875453)

# %%
r, p_val = stats.spearmanr(df['tip'], df['fare'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: there is no relationship.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.30804802505745693
# P-value: 1.8889690809484477e-141
# Reject null hypothesis: there is no relationship.

# %%
# Compute Pearson correlation
r, p_val = stats.pearsonr(df['tip'], df['fare'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: Significant correlation exists.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.4886124004721835
# P-value: 0.0
# Reject null hypothesis: Significant correlation exists.

# %%
# Compute Pearson correlation
r, p_val = stats.pearsonr(df['tip'], df['distance'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: Significant correlation exists.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.4525886565083947
# P-value: 1.8e-322
# Reject null hypothesis: Significant correlation exists.

# %%
# Compute Pearson correlation
r, p_val = stats.pearsonr(df['tip'], df['total'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: Significant correlation exists.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.6461857919756505
# P-value: 0.0
# Reject null hypothesis: Significant correlation exists.

# %%
df['pickup']
# Out:
# 0      2019-03-23 20:21:09
# 1      2019-03-04 16:11:55
# 2      2019-03-27 17:53:01
# 3      2019-03-10 01:23:59
# 4      2019-03-30 13:27:42
#                ...
# 6428   2019-03-31 09:51:53
# 6429   2019-03-31 17:38:00
# 6430   2019-03-23 22:55:18
# 6431   2019-03-04 10:09:25
# 6432   2019-03-13 19:31:22
# Name: pickup, Length: 6433, dtype: datetime64[ns]

# %%
df['pickup'].dt.day #day_name()
# Out:
# 0       23
# 1        4
# 2       27
# 3       10
# 4       30
#         ..
# 6428    31
# 6429    31
# 6430    23
# 6431     4
# 6432    13
# Name: pickup, Length: 6433, dtype: int32

# %%
df['pickup'].dt.month #month_name()
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 6428    3
# 6429    3
# 6430    3
# 6431    3
# 6432    3
# Name: pickup, Length: 6433, dtype: int32

# %%
df['pickup'].dt.year
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4       2019
#         ...
# 6428    2019
# 6429    2019
# 6430    2019
# 6431    2019
# 6432    2019
# Name: pickup, Length: 6433, dtype: int32

# %%
df['pickup'].dt.quarter
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6428    1
# 6429    1
# 6430    1
# 6431    1
# 6432    1
# Name: pickup, Length: 6433, dtype: int32

# %%
df['pickup'].dt.hour #dt.minute , dt.second
# Out:
# 0       20
# 1       16
# 2       17
# 3        1
# 4       13
#         ..
# 6428     9
# 6429    17
# 6430    22
# 6431    10
# 6432    19
# Name: pickup, Length: 6433, dtype: int32

# %%
len(df['pickup'].unique())
# Out:
# 6414

# %%
df['pickup_month']=df['pickup'].dt.month_name()

# %%
df['pickup_year']=df['pickup'].dt.year
df['pickup_day']=df['pickup'].dt.day
df['pickup_dayname']=df['pickup'].dt.day_name()

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough pickup_month  \
# 0    UN/Turtle Bay South      Manhattan       Manhattan        March
# 1  Upper West Side South      Manhattan       Manhattan        March
# 2           West Village      Manhattan       Manhattan        March
# 3         Yorkville West      Manhattan       Manhattan        March
# 4         Yorkville West      Manhattan       Manhattan        March
#
#    pickup_year  pickup_day pickup_dayname
# 0         2019          23       Saturday
# 1         2019           4         Monday
# 2         2019          27      Wednesday
# 3         2019          10         Sunday
# 4         2019          30       Saturday

# %%
df.pickup_month.value_counts()
# Out:
# pickup_month
# March       6432
# February       1
# Name: count, dtype: int64

# %%
df['dropoff_month']=df['dropoff'].dt.month_name()
df['dropoff_year']=df['dropoff'].dt.year
df['dropoff_day']=df['dropoff'].dt.day
df['dropoff_dayname']=df['dropoff'].dt.day_name()

# %%
df['dropoff_hour']=df['dropoff'].dt.hour
df['dropoff_munite']=df['dropoff'].dt.minute
df['dropoff_second']=df['dropoff'].dt.second
df['dropoff_quarter']=df['dropoff'].dt.quarter

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment  ... pickup_day pickup_dayname  \
# 0    0.0  12.95  yellow  credit card  ...         23       Saturday
# 1    0.0   9.30  yellow         cash  ...          4         Monday
# 2    0.0  14.16  yellow  credit card  ...         27      Wednesday
# 3    0.0  36.95  yellow  credit card  ...         10         Sunday
# 4    0.0  13.40  yellow  credit card  ...         30       Saturday
#
#   dropoff_month dropoff_year dropoff_day  dropoff_dayname  dropoff_hour  \
# 0         March         2019          23         Saturday            20
# 1         March         2019           4           Monday            16
# 2         March         2019          27        Wednesday            18
# 3         March         2019          10           Sunday             1
# 4         March         2019          30         Saturday            13
#
#   dropoff_munite dropoff_second  dropoff_quarter
# 0             27             24                1
# 1             19              0                1
# 2              0             25                1
# 3             49             51                1
# 4             37             14                1
#
# [5 rows x 26 columns]

# %%
df['pickup_hour']=df['pickup'].dt.hour

# %%
from scipy import stats

r, p_val = stats.spearmanr(df['tip'], df['pickup_hour'])

print("Correlation:", r)
print("P-value:", p_val)

alpha = 0.05

if p_val < alpha:
    print("Reject null hypothesis: There IS a significant relationship")
else:
    print("Fail to reject null hypothesis: There is NO significant relationship")
# Out:
# Correlation: 0.05998509725758288
# P-value: 1.4752130874564108e-06
# Reject null hypothesis: There IS a significant relationship

# %%
from scipy import stats

r, p_val = stats.spearmanr(df['tip'], df['dropoff_hour'])

print("Correlation:", r)
print("P-value:", p_val)

alpha = 0.05

if p_val < alpha:
    print("Reject null hypothesis: There IS a significant relationship")
else:
    print("Fail to reject null hypothesis: There is NO significant relationship")
# Out:
# Correlation: 0.06045074947716206
# P-value: 1.2221821670578065e-06
# Reject null hypothesis: There IS a significant relationship

# %%
from scipy import stats

r, p_val = stats.spearmanr(df['tip'], df['pickup_month'])

print("Correlation:", r)
print("P-value:", p_val)

alpha = 0.05

if p_val < alpha:
    print("Reject null hypothesis: There IS a significant relationship")
else:
    print("Fail to reject null hypothesis: There is NO significant relationship")
# Out:
# Correlation: 0.014171947347057906
# P-value: 0.255742691140195
# Fail to reject null hypothesis: There is NO significant relationship

# %%
from scipy import stats

r, p_val = stats.spearmanr(df['tip'], df['pickup_day'])

print("Correlation:", r)
print("P-value:", p_val)

alpha = 0.05

if p_val < alpha:
    print("Reject null hypothesis: There IS a significant relationship")
else:
    print("Fail to reject null hypothesis: There is NO significant relationship")
# Out:
# Correlation: 0.010687842621826532
# P-value: 0.39139689532052413
# Fail to reject null hypothesis: There is NO significant relationship

# %%
from scipy import stats

r, p_val = stats.spearmanr(df['tip'], df['pickup_year'])

print("Correlation:", r)
print("P-value:", p_val)

alpha = 0.05

if p_val < alpha:
    print("Reject null hypothesis: There IS a significant relationship")
else:
    print("Fail to reject null hypothesis: There is NO significant relationship")
# Out:
# Correlation: nan
# P-value: nan
# Fail to reject null hypothesis: There is NO significant relationship
# /tmp/ipython-input-2091430436.py:3: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p_val = stats.spearmanr(df['tip'], df['pickup_year'])

# %%
from scipy import stats

r, p_val = stats.spearmanr(df['tip'], df['dropoff_day'])

print("Correlation:", r)
print("P-value:", p_val)

alpha = 0.05

if p_val < alpha:
    print("Reject null hypothesis: There IS a significant relationship")
else:
    print("Fail to reject null hypothesis: There is NO significant relationship")
# Out:
# Correlation: 0.011511101525117065
# P-value: 0.3559496754636271
# Fail to reject null hypothesis: There is NO significant relationship

# %%
from scipy import stats

r, p_val = stats.spearmanr(df['tip'], df['dropoff_month'])

print("Correlation:", r)
print("P-value:", p_val)

alpha = 0.05

if p_val < alpha:
    print("Reject null hypothesis: There IS a significant relationship")
else:
    print("Fail to reject null hypothesis: There is NO significant relationship")
# Out:
# Correlation: 0.020043718086637158
# P-value: 0.10795016237184796
# Fail to reject null hypothesis: There is NO significant relationship

# %%
from scipy import stats

r, p_val = stats.spearmanr(df['tip'], df['dropoff_year'])

print("Correlation:", r)
print("P-value:", p_val)

alpha = 0.05

if p_val < alpha:
    print("Reject null hypothesis: There IS a significant relationship")
else:
    print("Fail to reject null hypothesis: There is NO significant relationship")
# Out:
# Correlation: nan
# P-value: nan
# Fail to reject null hypothesis: There is NO significant relationship
# /tmp/ipython-input-378464192.py:3: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p_val = stats.spearmanr(df['tip'], df['dropoff_year'])

# %%
from scipy import stats

r, p_val = stats.spearmanr(df['tip'], df['dropoff_munite'])

print("Correlation:", r)
print("P-value:", p_val)

alpha = 0.05

if p_val < alpha:
    print("Reject null hypothesis: There IS a significant relationship")
else:
    print("Fail to reject null hypothesis: There is NO significant relationship")
# Out:
# Correlation: -0.006185434444410824
# P-value: 0.6198822773775354
# Fail to reject null hypothesis: There is NO significant relationship

# %%
from scipy import stats

r, p_val = stats.spearmanr(df['tip'], df['dropoff_quarter'])

print("Correlation:", r)
print("P-value:", p_val)

alpha = 0.05

if p_val < alpha:
    print("Reject null hypothesis: There IS a significant relationship")
else:
    print("Fail to reject null hypothesis: There is NO significant relationship")
# Out:
# Correlation: -0.014171947347057906
# P-value: 0.255742691140195
# Fail to reject null hypothesis: There is NO significant relationship

# %%
from scipy import stats

r, p_val = stats.spearmanr(df['tip'], df['dropoff_second'])

print("Correlation:", r)
print("P-value:", p_val)

alpha = 0.05

if p_val < alpha:
    print("Reject null hypothesis: There IS a significant relationship")
else:
    print("Fail to reject null hypothesis: There is NO significant relationship")
# Out:
# Correlation: -7.740271567382785e-05
# P-value: 0.9950475985323795
# Fail to reject null hypothesis: There is NO significant relationship

# %%
cols_to_drop= [
    'pickup_month',
    'pickup_day',
    'pickup_year',
    'dropoff_day',
    'dropoff_month',
    'dropoff_year',
    'dropoff_munite',
    'dropoff_second',
    'dropoff_quarter'
]

# %%
df.drop(columns=cols_to_drop, inplace=True)

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough pickup_dayname  \
# 0    UN/Turtle Bay South      Manhattan       Manhattan       Saturday
# 1  Upper West Side South      Manhattan       Manhattan         Monday
# 2           West Village      Manhattan       Manhattan      Wednesday
# 3         Yorkville West      Manhattan       Manhattan         Sunday
# 4         Yorkville West      Manhattan       Manhattan       Saturday
#
#   dropoff_dayname  dropoff_hour  trip_duration_minutes
# 0        Saturday            20               6.250000
# 1          Monday            16               7.083333
# 2       Wednesday            18               7.400000
# 3          Sunday             1              25.866667
# 4        Saturday            13               9.533333

# %%
from sklearn.preprocessing import LabelEncoder

cat_cols = [
    'color',
    'payment',
    'pickup_zone',
    'dropoff_zone',
    'pickup_borough',
    'dropoff_borough',
    'pickup_dayname',
    'dropoff_dayname'
]

# keep only columns that actually exist in df
cat_cols = [col for col in cat_cols if col in df.columns]

# %%
le = LabelEncoder()

for col in cat_cols:
    df[col] = le.fit_transform(df[col].astype(str))

# %%
df[cat_cols].head()
# Out:
#    color  payment  pickup_zone  dropoff_zone  pickup_borough  dropoff_borough  \
# 0      1        1           99           176               2                2
# 1      1        0          174           182               2                2
# 2      1        1            1           190               2                2
# 3      1        1           86           202               2                2
# 4      1        1          116           202               2                2
#
#    pickup_dayname  dropoff_dayname
# 0               2                2
# 1               1                1
# 2               6                6
# 3               3                3
# 4               2                2

# %%
x=df.drop('tip',axis=1)
y=df.tip

# %%
print(x.shape)
print(y.shape)
# Out:
# (6433, 18)
# (6433,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (4824, 18)
# (4824,)
# (1609, 18)
# (1609,)

# %%
print(x_train.dtypes)
# Out:
# pickup                   datetime64[ns]
# dropoff                  datetime64[ns]
# passengers                        int64
# distance                        float64
# fare                            float64
# tolls                           float64
# total                           float64
# color                             int64
# payment                           int64
# pickup_zone                       int64
# dropoff_zone                      int64
# pickup_borough                    int64
# dropoff_borough                   int64
# pickup_dayname                    int64
# dropoff_dayname                   int64
# dropoff_hour                      int32
# trip_duration_minutes           float64
# pickup_hour                       int32
# dtype: object

# %%
datetime_cols = x_train.select_dtypes(include=['datetime64[ns]']).columns

x_train = x_train.drop(columns=datetime_cols)
x_test = x_test.drop(columns=datetime_cols)

# %%
print(x_train.dtypes)
# Out:
# passengers                 int64
# distance                 float64
# fare                     float64
# tolls                    float64
# total                    float64
# color                      int64
# payment                    int64
# pickup_zone                int64
# dropoff_zone               int64
# pickup_borough             int64
# dropoff_borough            int64
# pickup_dayname             int64
# dropoff_dayname            int64
# dropoff_hour               int32
# trip_duration_minutes    float64
# pickup_hour                int32
# dtype: object

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-2.19993017e-03, -5.16757968e-03, -7.29288987e-01, -7.56942329e-01,
#         7.71017191e-01, -1.30511777e+00,  4.56986182e-01, -8.14189570e-04,
#        -1.29295564e-03,  1.93935372e-01, -2.33852418e-02, -3.12635281e-02,
#         3.02363190e-02, -2.19470502e-03, -1.53620131e-02, -1.51930886e-02])

# %%
model.intercept_
# Out:
# np.float64(-1.3624066524109637)

# %%
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
train_score = model.score(x_train, y_train)
print("Model training Score:",train_score)
# Out:
# Model training Score: 0.9235154581233298

# %%
test_score = model.score(x_test, y_test)
print("Model training Score:",test_score)
# Out:
# Model training Score: 0.9280654246695077

# %%
from sklearn.metrics import root_mean_squared_error , mean_squared_error , mean_absolute_error,r2_score

# %%
root_mean_squared_error(y_train,y_train_pred)
# Out:
# 0.6732120189175285

# %%
mean_squared_error(y_train,y_train_pred)
# Out:
# 0.4532144224150147

# %%
mean_absolute_error(y_train,y_train_pred)
# Out:
# 0.44534317216634434

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.9235154581233298

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.9280654246695077

# %% [markdown]
# **********Regression*************

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Position_Salaries.csv'
dataset = pd.read_csv(path)

X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (10, 1)
# y shape: (10,)

# %%
dataset.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
# Training the Linear Regression model on the whole dataset
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)

# Training the Polynomial Regression model on the whole dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)

print("✅ Models Trained Successfully!")
# Out:
# ✅ Models Trained Successfully!

# %%
plt.scatter(X,y,color="red")
plt.title("plot between varibles")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(X,y,color="red")
plt.plot(X,lin_reg.predict(X),color="blue")
plt.title("Truth or Bluff (Linear Regression)")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()

# %%
# Visualising the Polynomial Regression results
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
linear_predict = lin_reg.predict([[9.5]])
print("Linear Regression Prediction:", linear_predict)
# Out:
# Linear Regression Prediction: [573015.15151515]

# %%
poly_predict = lin_reg_2.predict(poly_reg.transform([[9.5]]))
print("Polynomial Regression Prediction:", poly_predict)
# Out:
# Polynomial Regression Prediction: [724730.02258158]

# %%
#linear
y_pred=lin_reg.predict(X)
print("R2 Score: ",r2_score(y,y_pred))
print("MSE: ",mean_squared_error(y,y_pred))
print("MAE: ",mean_absolute_error(y,y_pred))
print("RMSE: ",root_mean_squared_error(y,y_pred))
# Out:
# R2 Score:  0.6690412331929895
# MSE:  26695878787.878784
# MAE:  128454.54545454546
# RMSE:  163388.73519272613

# %%
#polynomial

y_poly_pred = lin_reg_2.predict(poly_reg.transform(X))

mse_poly = mean_squared_error(y, y_poly_pred)
print("Mean Squared Error:", mse_poly)

mae_poly = mean_absolute_error(y,y_poly_pred)
print("Mean Absolute Error:", mae_poly)

r2_poly = r2_score(y, y_poly_pred)
print("R-squared :", r2_poly)
print("RMSE: ",root_mean_squared_error(y,y_pred))
# Out:
# Mean Squared Error: 210343822.84381685
# Mean Absolute Error: 12681.818181828514
# R-squared : 0.9973922891706614
# RMSE:  163388.73519272613
